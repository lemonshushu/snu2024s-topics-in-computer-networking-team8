http3_val_loss = [1.9554731845855713, 1.5778712034225464, 0.9248458743095398, 0.7493840456008911, 0.6052266359329224, 0.623926043510437, 0.5472051501274109, 0.5463051795959473, 0.4945642948150635, 0.47023433446884155, 0.3962291181087494, 0.3588099777698517, 0.3877907991409302, 0.34555497765541077, 0.37770095467567444, 0.3799310624599457, 0.29505470395088196, 0.34447455406188965, 0.304834246635437, 0.29245588183403015, 0.32193148136138916, 0.28726696968078613, 0.27543243765830994, 0.2714023292064667, 0.282664030790329, 0.2817955017089844, 0.2861005365848541, 0.3008260726928711, 0.2998928427696228, 0.28126075863838196, 0.28315186500549316, 0.2830440104007721, 0.2737866938114166, 0.2730354368686676, 0.2783358693122864, 0.27478620409965515, 0.2727894186973572, 0.28150245547294617, 0.2793342173099518, 0.2768433392047882]

http2_test_loss = 0.2842370867729187
http2_test_accuracy = 0.9232588410377502

http3_test_loss = 0.29380273818969727
http3_test_accuracy = 0.9204335808753967


# Cross-test results
http2_test_loss_with_http3_data = 1.232239842414856
http2_test_accuracy_with_http3_data = 0.7531707286834717
http3_test_loss_with_http2_data = 1.5799058675765991
http3_test_accuracy_with_http2_data = 0.7016336917877197

plt.rcParams['font.size'] = 22
plt.rcParams['text.usetex'] = True

# %%
# Plot 1. `http2` model accuracy
# Plot 2. `http2` model loss
# Plot 3. `http3` model accuracy
# Plot 4. `http3` model loss

# Plot 1
plt.figure(figsize=(12, 8))
plt.plot(range(1, N_EPOCHS + 1), http2_train_accuracy, label='Training', color='green', linewidth=1.5)
plt.plot(range(1, N_EPOCHS + 1), http2_val_accuracy, label='Validation', color='orange', linewidth=1.5)
plt.xlim(10, N_EPOCHS)
plt.ylim(0.68, 0.95)
plt.yticks([0.70, 0.75, 0.8, 0.85, 0.9, 0.95])

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.axhline(http2_test_accuracy, color='r', linestyle='--', label=r'Test (w/ \texttt{http2} data)', linewidth=2)
plt.axhline(http2_test_accuracy_with_http3_data, color='indianred', linestyle='-.', label=r'Test (w/ \texttt{http3} data)', linewidth=2)

plt.text(10.5, http2_test_accuracy + 0.005, 'Test accuracy = ' + f'{http2_test_accuracy:.3f}', color='r', fontsize=22)
plt.text(10.5, http2_test_accuracy_with_http3_data - 0.0155, r'Test accuracy with \texttt{http3} test data = ' + f'{http2_test_accuracy_with_http3_data:.3f}', color='indianred', fontsize=22)

plt.title(r'Accuracy by epoch (\texttt{http2} model)', fontsize=30)
plt.legend()
plt.grid(True)

plt.show()

# %%
# Plot 2
plt.figure(figsize=(12, 8))
plt.plot(range(1, N_EPOCHS + 1), http2_train_loss, label='Training', color='green', linewidth=1.5)
plt.plot(range(1, N_EPOCHS + 1), http2_val_loss, label='Validation', color='orange', linewidth=1.5)
plt.xlim(10, N_EPOCHS)
plt.ylim(0.1, 1.7)

plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.axhline(http2_test_loss, color='r', linestyle='--', label=r'Test (w/ \texttt{http2} data)', linewidth=2)
plt.axhline(http2_test_loss_with_http3_data, color='indianred', linestyle='-.', label=r'Test (w/ \texttt{http3} data)', linewidth=2)

plt.text(N_EPOCHS - 10, http2_test_loss + 0.03, 'Test loss = ' + f'{http2_test_loss:.3f}', color='r', fontsize=22)
plt.text(N_EPOCHS - 16, http2_test_loss_with_http3_data + 0.03, r'Test loss with \texttt{http3} test data = ' + f'{http2_test_loss_with_http3_data:.3f}', color='indianred', fontsize=22)

plt.title(r'Loss by epoch (\texttt{http2} model)', fontsize=30)
plt.legend()
plt.grid(True)

plt.show()

# %%
# Plot 3
plt.figure(figsize=(12, 8))
plt.plot(range(1, N_EPOCHS + 1), http3_train_accuracy, label='Training', color='green', linewidth=1.5)
plt.plot(range(1, N_EPOCHS + 1), http3_val_accuracy, label='Validation', color='orange', linewidth=1.5)
plt.xlim(10, N_EPOCHS)
plt.ylim(0.68, 0.95)
plt.yticks([0.70, 0.75, 0.8, 0.85, 0.9, 0.95])

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.axhline(http3_test_accuracy, color='r', linestyle='--', label=r'Test (w/ \texttt{http3} data)', linewidth=2)
plt.axhline(http3_test_accuracy_with_http2_data, color='indianred', linestyle='-.', label=r'Test (w/ \texttt{http2} data)', linewidth=2)

plt.text(10.5, http3_test_accuracy + 0.005, 'Test accuracy = ' + f'{http3_test_accuracy:.3f}', color='r', fontsize=22)
plt.text(10.5, http3_test_accuracy_with_http2_data + 0.005, r'Test accuracy with \texttt{http2} test data = ' + f'{http3_test_accuracy_with_http2_data:.3f}', color='indianred', fontsize=22)

plt.title(r'Accuracy by epoch (\texttt{http3} model)', fontsize=30)
plt.legend()
plt.grid(True)

plt.show()

# %%
# Plot 4
plt.figure(figsize=(12, 8))
plt.plot(range(1, N_EPOCHS + 1), http3_train_loss, label='Training', color='green', linewidth=1.5)
plt.plot(range(1, N_EPOCHS + 1), http3_val_loss, label='Validation', color='orange', linewidth=1.5)
plt.xlim(10, N_EPOCHS)
plt.ylim(0.1, 1.7)

plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.axhline(http3_test_loss, color='r', linestyle='--', label=r'Test (w/ \texttt{http3} data)', linewidth=2)
plt.axhline(http3_test_loss_with_http2_data, color='indianred', linestyle='-.', label=r'Test (w/ \texttt{http2} data)', linewidth=2)

plt.text(N_EPOCHS - 10, http3_test_loss + 0.03, 'Test loss = ' + f'{http3_test_loss:.3f}', color='r', fontsize=22)
plt.text(N_EPOCHS - 16, http3_test_loss_with_http2_data + 0.03, r'Test loss with \texttt{http2} test data = ' + f'{http3_test_loss_with_http2_data:.3f}', color='indianred', fontsize=22)

plt.title(r'Loss by epoch (\texttt{http3} model)', fontsize=30)
plt.legend()
plt.grid(True)

plt.show()
